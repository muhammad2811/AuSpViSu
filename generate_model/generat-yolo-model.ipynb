# %%
# !unzip /content/dataset.zip
# Out:
# Archive:  /content/dataset.zip
#   inflating: dataset/data.yaml
#    creating: dataset/test/
#    creating: dataset/test/images/
#   inflating: dataset/test/images/gool_0045.jpg
#   inflating: dataset/test/images/gool_0046.jpg
#   inflating: dataset/test/images/gool_0047.jpg
#   inflating: dataset/test/images/gool_0048.jpg
#   inflating: dataset/test/images/gool_0049.jpg
#   inflating: dataset/test/images/rc_0069.jpg
#   inflating: dataset/test/images/rc_0070.jpg
#   inflating: dataset/test/images/rc_0071.jpg
#   inflating: dataset/test/images/rc_0072.jpg
#   inflating: dataset/test/images/rc_0073.jpg
#   inflating: dataset/test/images/rc_0074.jpg
#   inflating: dataset/test/images/rc_0075.jpg
#   inflating: dataset/test/images/rc_0076.jpg
#   inflating: dataset/test/images/rc_0077.jpg
#   inflating: dataset/test/images/ss_0063.jpg
#   inflating: dataset/test/images/ss_0064.jpg
#   inflating: dataset/test/images/ss_0065.jpg
#   inflating: dataset/test/images/ss_0066.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 13.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
# !yolo task=detect mode=train model=/content/yolov8s.pt data=/content/dataset/data.yaml epochs=15 imgsz=640 batch=8 project=/content/training_results name=detect
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 189MB/s]
# Ultralytics YOLOv8.2.46 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/training_results/detect/weights/best.pt conf=0.55 source=/content/sample
# Out:
# Ultralytics YOLOv8.2.46 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/8 /content/sample/2024-06-29 (5).png: 384x640 1 sb, 1 ht, 1 at, 419.2ms
# image 2/8 /content/sample/2024-06-29 (6).png: 384x640 1 sb, 1 gool, 1 ht, 1 at, 1 np, 415.8ms
# image 3/8 /content/sample/2024-06-29 (7).png: 384x640 1 sb, 1 rc, 1 ht, 1 at, 1 np, 389.0ms
# image 4/8 /content/sample/2024-06-29 (8).png: 384x640 1 sb, 1 ss, 1 ht, 1 at, 1 np, 386.4ms
# image 5/8 /content/sample/gool_0047.jpg: 384x640 1 sb, 1 gool, 1 ht, 1 at, 1 np, 351.8ms
# image 6/8 /content/sample/rc_0069.jpg: 384x640 1 sb, 1 ht, 1 at, 1 np, 403.3ms
# image 7/8 /content/sample/ss_0069.jpg: 384x640 1 sb, 1 ss, 1 ht, 1 at, 1 np, 373.0ms
# image 8/8 /content/sample/yc_0065.jpg: 384x640 1 sb, 1 yc, 1 ht, 1 at, 1 np, 364.6ms
# Speed: 3.3ms preprocess, 387.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ...

# %%
from google.colab import files
files.download('/content/training_results/detect/weights/best.pt')
